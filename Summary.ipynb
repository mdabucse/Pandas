# %%
pip install pandas-summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from pandas_summary import DataFrameSummary

# %%
k=pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df=DataFrameSummary(k)

# %%
df.columns_stats
# Out:
#              longitude latitude housing_median_age total_rooms total_bedrooms  \
# counts            3000     3000               3000        3000           3000
# uniques            607      587                 52        2215           1055
# missing              0        0                  0           0              0
# missing_perc        0%       0%                 0%          0%             0%
# types          numeric  numeric            numeric     numeric        numeric
#
#              population households median_income median_house_value
# counts             3000       3000          3000               3000
# uniques            1802       1026          2578               1784
# missing               0          0             0                  0
# missing_perc         0%         0%            0%                 0%
# types           numeric    numeric       numeric            numeric

# %%
dfs=pd.DataFrame(k)

# %%
dfs
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
dfs['longitude']
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
dfs['longitude'].head()
# Out:
# 0   -122.05
# 1   -118.30
# 2   -117.81
# 3   -118.36
# 4   -119.67
# Name: longitude, dtype: float64

# %%
dfs['longitude'].nunique()
# Out:
# 607
